# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("../data/raw/train_delay.csv")
df.head()
# Out:
#    train_number    train_type source destination  distance_km day_of_week  \
# 0         12574      Shatabdi    MAS        NDLS         1086      Monday
# 1         12794     Superfast   NDLS         CNB          693    Thursday
# 2         12951     Superfast   PNBE         HWH          843      Sunday
# 3         12957  Vande Bharat    HWH         DDU         1283    Saturday
# 4         12452      Rajdhani   CSMT         SBC         1476    Saturday
#
#    month  delay_minutes
# 0      7             45
# 1      3              8
# 2      8             37
# 3      4             23
# 4     10             18

# %%
profile = ProfileReport(
    df,
    title="Indian Railways Train Delay – EDA Report",
    explorative=True
)

# %%
profile.to_file("../Reports/indian_railways_delay_profiling.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
